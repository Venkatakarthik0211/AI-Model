# %%
pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 4.0 MB/s eta 0:00:00m eta 0:00:010:01:010m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 773.9/773.9 KB 9.7 MB/s eta 0:00:00m eta 0:00:010:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 KB 9.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer
from collections import Counter
import matplotlib.pyplot as plt
text = open('read.txt', encoding='utf-8').read()
lc = text.lower()
clear = lc.translate(str.maketrans('','',string.punctuation))

# %%
tokenized_words = word_tokenize(clear,'english')
final = []
for word in tokenized_words:
    if word not in stopwords.words('english'):
        final.append(word)
print(final)
# Out:
# ['upon', 'time', 'quaint', 'little', 'town', 'lived', 'young', 'woman', 'named', 'emily', 'emily', 'known', 'vibrant', 'spirit', 'contagious', 'laughter', 'echoed', 'cobblestone', 'streets', 'heart', 'full', 'dreams', 'aspirations', 'unyielding', 'passion', 'life', 'one', 'day', 'emily', 'strolled', 'town', 'square', 'noticed', 'charming', 'bookstore', 'tucked', 'away', 'corner', 'aroma', 'old', 'books', 'promise', 'new', 'adventures', 'drew', 'inside', 'bell', 'door', 'chimed', 'announcing', 'arrival', 'little', 'know', 'bookstore', 'would', 'become', 'setting', 'tale', 'joy', 'heartbreak', 'emily', 'perused', 'shelves', 'fingers', 'danced', 'spines', 'various', 'novels', 'eyes', 'sparkled', 'excitement', 'discovered', 'hidden', 'gems', 'literary', 'treasures', 'lost', 'world', 'words', 'felt', 'profound', 'connection', 'characters', 'emotional', 'journeys', 'among', 'shelves', 'emily', 'stumbled', 'upon', 'weathered', 'leatherbound', 'book', 'title', 'whispers', 'heart', 'intrigued
# ...

# %%
# Create an instance of the SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# Create a dictionary to store results
results = {'positive': 0, 'negative': 0}

# Determine sentiment for each word and count occurrences
for word, sentiment in w.items():
    sentiment_score = sia.polarity_scores(word.strip())
    
    # Check the compound score to determine overall sentiment
    if sentiment_score['compound'] >= 0.05:
        results['positive'] += 1
    elif sentiment_score['compound'] <= -0.05:
        results['negative'] += 1

# Print or use results as needed
print(results)

# Create a bar plot
plt.bar(results.keys(), results.values(), color=['green', 'red'])

# Set equal spacing between bars
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.title('Sentiment Analysis (Excluding Neutral Words)')

plt.show()
# Out:
# Counter({' attached': 2, ' attracted': 1, ' lost': 1, ' sad': 1})

# %%
# Out:
# {'positive': 1, 'negative': 2}
